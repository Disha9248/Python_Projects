# %%
# Importing libraries

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Importing dataset

df = pd.read_csv(r'C:\Users\disha\Downloads\All Projects\Python Projects\netflix\Dataset.csv')

# %%
# Display first 5 rows.

df.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
# Dimensions of the DataFrame.

df.shape
# Out:
# (7789, 11)

# %%
# DataFrame summary.

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      5401 non-null   object
#  4   Cast          7071 non-null   object
#  5   Country       7282 non-null   object
#  6   Release_Date  7779 non-null   object
#  7   Rating        7782 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
# dtypes: object(11)
# memory usage: 669.5+ KB

# %% [markdown]
# # Netflix Data Analysis

# %% [markdown]
# ### Question 1 : Is there any Duplicate Record in this dataset ? If yes, then remove the duplicate records.

# %%
# Checking duplicates

df.duplicated().sum()
# Out:
# 2

# %%
# Displaying duplicate

df[df.duplicated()]
# Out:
#      Show_Id Category              Title        Director  \
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#            Release_Date Rating Duration  \
# 6300      April 5, 2019  TV-MA   97 min
# 6622  September 4, 2020  TV-MA   94 min
#
#                                        Type  \
# 6300  Dramas, Independent Movies, Thrillers
# 6622   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6300  When two would-be robbers accidentally kill a ...
# 6622  A disillusioned security guard transforms into...

# %%
# Dropping duplicate values

df = df.drop_duplicates()

# %%
# Checking duplicates

df.duplicated().sum()
# Out:
# 0

# %%
# Dimensions of the DataFrame.

df.shape
# Out:
# (7787, 11)

# %% [markdown]
# ### Question 2 : Is there any Null Value present in any column ? Show with Heat-map.

# %%
# Checking null value

df.isnull().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
# Visualize Heat_map 

sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %% [markdown]
# ### Question 3 : For 'House of Cards', what is the Show Id and Who is the Director of this show ?

# %%
# Analyzing data

df.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description
# 0  In a future where the elite inhabit an island ...
# 1  After a devastating earthquake hits Mexico Cit...

# %%
# Record of House Of Cards

df[df['Title'] == 'House of Cards'][['Title','Show_Id','Director']]
# Out:
#                Title Show_Id  \
# 2832  House of Cards   s2833
#
#                                                Director
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...

# %% [markdown]
# ### Question 4 : In which year the highest number of the TV Shows & Movies were released with Bar Graph.

# %%
# Analyzing data

df.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description
# 0  In a future where the elite inhabit an island ...
# 1  After a devastating earthquake hits Mexico Cit...

# %%
# Checking data type

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7787 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7787 non-null   object
#  1   Category      7787 non-null   object
#  2   Title         7787 non-null   object
#  3   Director      5399 non-null   object
#  4   Cast          7069 non-null   object
#  5   Country       7280 non-null   object
#  6   Release_Date  7777 non-null   object
#  7   Rating        7780 non-null   object
#  8   Duration      7787 non-null   object
#  9   Type          7787 non-null   object
#  10  Description   7787 non-null   object
# dtypes: object(11)
# memory usage: 730.0+ KB

# %%
# Changing data type

df['Release_Date'] = df['Release_Date'].str.strip()
df['Release_Date'] = pd.to_datetime(df['Release_Date'])

# %%
# Adding new column

df['year'] = df['Release_Date'].dt.year

# %%
# Analyzing data

df.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil   2020-08-14
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico   2016-12-23
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1  TV-MA     93 min                       Dramas, International Movies
#
#                                          Description    year
# 0  In a future where the elite inhabit an island ...  2020.0
# 1  After a devastating earthquake hits Mexico Cit...  2016.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      5401 non-null   object
#  4   Cast          7071 non-null   object
#  5   Country       7282 non-null   object
#  6   Release_Date  7779 non-null   datetime64[ns]
#  7   Rating        7782 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
#  11  year          7779 non-null   float64
# dtypes: datetime64[ns](1), float64(1), object(10)
# memory usage: 730.3+ KB

# %%
# Changing data type of year column

df['year'] = df['year'].astype('Int64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      5401 non-null   object
#  4   Cast          7071 non-null   object
#  5   Country       7282 non-null   object
#  6   Release_Date  7779 non-null   datetime64[ns]
#  7   Rating        7782 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
#  11  year          7779 non-null   Int64
# dtypes: Int64(1), datetime64[ns](1), object(10)
# memory usage: 738.0+ KB

# %%
# Analyzing data

df.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil   2020-08-14
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico   2016-12-23
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1  TV-MA     93 min                       Dramas, International Movies
#
#                                          Description  year
# 0  In a future where the elite inhabit an island ...  2020
# 1  After a devastating earthquake hits Mexico Cit...  2016

# %%
# year with the highest number of the TV Shows & Movies

df.groupby(['year'])['Category'].count().sort_values(ascending = False)
# Out:
# year
# 2019    2154
# 2020    2010
# 2018    1685
# 2017    1225
# 2016     443
# 2021     117
# 2015      88
# 2014      25
# 2011      13
# 2013      11
# 2012       3
# 2008       2
# 2009       2
# 2010       1
# Name: Category, dtype: int64

# %%
# Visualization of year with the highest number of the TV Shows & Movies

year_wise_data = df.groupby(['year'])['Category'].count().sort_values(ascending = False)

df['year'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='year'>

# %% [markdown]
# ### Question 5 : How many Movies & TV Shows are in the dataset ? Show with Bar Graph.

# %%
# Analyzing data

df.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil   2020-08-14
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico   2016-12-23
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1  TV-MA     93 min                       Dramas, International Movies
#
#                                          Description  year
# 0  In a future where the elite inhabit an island ...  2020
# 1  After a devastating earthquake hits Mexico Cit...  2016

# %%
# Movies & TV Shows in the dataset

df['Category'].value_counts()
# Out:
# Category
# Movie      5379
# TV Show    2410
# Name: count, dtype: int64

# %%
# Visualization of Movies & TV Shows in the dataset

sns.barplot(df['Category'].value_counts())
# Out:
# <Axes: xlabel='Category', ylabel='count'>

# %% [markdown]
# ### Question 6 : Show all the Movies that were released in year 2000.

# %%
# Analyzing data 

df.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil   2020-08-14
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico   2016-12-23
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1  TV-MA     93 min                       Dramas, International Movies
#
#                                          Description  year
# 0  In a future where the elite inhabit an island ...  2020
# 1  After a devastating earthquake hits Mexico Cit...  2016

# %%
# Movies that were released in year 2000.

df[df['year'] == 2000]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, year]
# Index: []

# %% [markdown]
# ### Question 7 : Show only the Titles of all TV Shows that were released in India only.

# %%
#  Titles of all TV Shows that were released in India

df[(df['Category'] == 'TV Show') & (df['Country'] == 'India')][['Category','Title','Country']]
# Out:
#      Category                               Title Country
# 86    TV Show        21 Sarfarosh: Saragarhi 1897   India
# 132   TV Show                           7 (Seven)   India
# 340   TV Show                        Agent Raghav   India
# 364   TV Show                        Akbar Birbal   India
# 533   TV Show                 Anjaan: Rural Myths   India
# ...       ...                                 ...     ...
# 6249  TV Show                The Creative Indians   India
# 6400  TV Show  The Golden Years with Javed Akhtar   India
# 6469  TV Show              The House That Made Me   India
# 7294  TV Show                          Typewriter   India
# 7705  TV Show                     Yeh Meri Family   India
#
# [71 rows x 3 columns]

# %% [markdown]
# ### Question 8 : Show Top 10 Directors, who gave the highest number of TV Shows & Movies to Netflix ?

# %%
# Analyzing data

df.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil   2020-08-14
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico   2016-12-23
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1  TV-MA     93 min                       Dramas, International Movies
#
#                                          Description  year
# 0  In a future where the elite inhabit an island ...  2020
# 1  After a devastating earthquake hits Mexico Cit...  2016

# %%
# Top 10 Directors, who gave the highest number of TV Shows & Movies to Netflix 

df.groupby(['Director'])['Show_Id'].count().sort_values(ascending = False).head(10)
# Out:
# Director
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Martin Scorsese           12
# Jay Chapman               12
# Youssef Chahine           12
# Steven Spielberg          10
# David Dhawan               9
# Robert Rodriguez           8
# Name: Show_Id, dtype: int64

# %% [markdown]
# ### Question 9 :  Show Records,where "Category is Movie & Type is Comedies" or "Country is United Kingdom".

# %%
# Analyzing data 

df.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil   2020-08-14
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico   2016-12-23
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1  TV-MA     93 min                       Dramas, International Movies
#
#                                          Description  year
# 0  In a future where the elite inhabit an island ...  2020
# 1  After a devastating earthquake hits Mexico Cit...  2016

# %%
# Records,where "Category is Movie & Type is Comedies" or "Country is United Kingdom"

df[(df['Category'] == 'Movie') & (df['Type'].str.contains('Comedies') | (df['Country'] == 'United Kingdom'))]
# Out:
#      Show_Id Category                              Title            Director  \
# 18       s19    Movie                             15-Aug  Swapnaneel Jayakar
# 19       s20    Movie                                '89                 NaN
# 33       s34    Movie                       #realityhigh    Fernando Lebrija
# 34       s35    Movie                              #Roxy     Michael Kennedy
# 36       s37    Movie                            #Selfie      Cristina Jacob
# ...      ...      ...                                ...                 ...
# 7766   s7765    Movie                               Zero          Aanand Rai
# 7771   s7770    Movie           Zindagi Na Milegi Dobara         Zoya Akhtar
# 7774   s7773    Movie  Zipi & Zape y la Isla del Capitan        Oskar Santos
# 7780   s7779    Movie                         Zombieland     Ruben Fleischer
# 7783   s7782    Movie                               Zoom        Peter Hewitt
#
# ...

# %% [markdown]
# ### Question 10 :  In how many movies/shows, Tom Cruise was cast ?

# %%
# Analyzing data 

df.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil   2020-08-14
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico   2016-12-23
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1  TV-MA     93 min                       Dramas, International Movies
#
#                                          Description  year
# 0  In a future where the elite inhabit an island ...  2020
# 1  After a devastating earthquake hits Mexico Cit...  2016

# %%
# Movies/shows,were Tom Cruise was cast

df[df['Cast'].str.contains('Tom Cruise', na=False)]
# Out:
#      Show_Id Category     Title              Director  \
# 3860   s3861    Movie  Magnolia  Paul Thomas Anderson
# 5071   s5071    Movie  Rain Man        Barry Levinson
#
#                                                    Cast        Country  \
# 3860  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...  United States
# 5071  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#      Release_Date Rating Duration                        Type  \
# 3860   2020-01-01      R  189 min  Dramas, Independent Movies
# 5071   2019-07-01      R  134 min      Classic Movies, Dramas
#
#                                             Description  year
# 3860  Through chance, human action, past history and...  2020
# 5071  A fast-talking yuppie is forced to slow down w...  2019

# %% [markdown]
# ### Question 11 : What are the different Ratings defined by Netflix ?

# %%
# Analyzing data 

df.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil   2020-08-14
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico   2016-12-23
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1  TV-MA     93 min                       Dramas, International Movies
#
#                                          Description  year
# 0  In a future where the elite inhabit an island ...  2020
# 1  After a devastating earthquake hits Mexico Cit...  2016

# %%
# Different Ratings defined by Netflix 

df['Rating'].unique()
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-PG', 'NR', 'TV-G', 'TV-Y', nan,
#        'TV-Y7', 'PG', 'G', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %% [markdown]
# ### Question 12 : How many Movies got the 'TV-14' rating, in Canada ?

# %%
# Movies that got the 'TV-14' rating, in Canada 

df[(df['Category'] == 'Movie') & (df['Rating'] == 'TV-14') & (df['Country'] == 'Canada')]
# Out:
#      Show_Id Category                                        Title  \
# 30       s31    Movie                             #cats_the_mewvie
# 34       s35    Movie                                        #Roxy
# 608     s609    Movie                               At First Light
# 1506   s1507    Movie                   Counterfeiting in Suburbia
# 3713   s3714    Movie                            Long Time Running
# 3956   s3957    Movie  Martin Matte: La vie, la mort...eh la la..!
# 5336   s5336    Movie                   Sadie's Last Days on Earth
# 5393   s5393    Movie                                   Sardaar ji
# 6062   s6062    Movie                  The Accountant of Auschwitz
# 7025   s7024    Movie                         The Wrong Babysitter
# 7041   s7040    Movie               There's Something in the Water
#
#                                     Director  \
# 30                          Michael Margolis
# 34                           Michael Kennedy
# ...

# %%
# Count of Movies that got the 'TV-14' rating, in Canada 

len(df[(df['Category'] == 'Movie') & (df['Rating'] == 'TV-14') & (df['Country'] == 'Canada')])
# Out:
# 11

# %% [markdown]
# ### Question 13 : How many TV Shows got the 'R' rating, after year 2018 ?

# %%
# TV Shows that got the 'R' rating, after year 2018

df[(df['Category'] == 'TV Show') & (df['Rating'] == 'R') & (df['year'] > 2018)]
# Out:
#      Show_Id Category                                Title           Director  \
# 6437   s6436  TV Show  The Hateful Eight: Extended Version  Quentin Tarantino
#
#                                                    Cast Country Release_Date  \
# 6437  Samuel L. Jackson, Kurt Russell, Jennifer Jaso...     NaN   2019-04-25
#
#      Rating  Duration      Type  \
# 6437      R  1 Season  TV Shows
#
#                                             Description  year
# 6437  Trapped at a stagecoach stop as a storm rages ...  2019

# %% [markdown]
# ### Question 14 : What is the maximum duration of a Movie on Netflix ?

# %%
# Analyzing data

df.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil   2020-08-14
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico   2016-12-23
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1  TV-MA     93 min                       Dramas, International Movies
#
#                                          Description  year
# 0  In a future where the elite inhabit an island ...  2020
# 1  After a devastating earthquake hits Mexico Cit...  2016

# %%
# Distinct Duration value

df['Duration'].unique()
# Out:
# array(['4 Seasons', '93 min', '78 min', '80 min', '123 min', '1 Season',
#        '95 min', '119 min', '118 min', '143 min', '103 min', '89 min',
#        '91 min', '149 min', '144 min', '124 min', '87 min', '110 min',
#        '128 min', '117 min', '100 min', '2 Seasons', '84 min', '99 min',
#        '90 min', '102 min', '104 min', '105 min', '56 min', '125 min',
#        '81 min', '97 min', '106 min', '107 min', '109 min', '44 min',
#        '75 min', '101 min', '3 Seasons', '37 min', '113 min', '114 min',
#        '130 min', '94 min', '140 min', '135 min', '82 min', '70 min',
#        '121 min', '92 min', '164 min', '53 min', '83 min', '116 min',
#        '86 min', '120 min', '96 min', '126 min', '129 min', '77 min',
#        '137 min', '148 min', '28 min', '122 min', '176 min', '85 min',
#        '22 min', '68 min', '111 min', '29 min', '142 min', '168 min',
#        '21 min', '59 min', '20 min', '98 min', '108 min', '76 min',
# ...

# %%
# Checking data type

df['Duration'].dtypes
# Out:
# dtype('O')

# %%
# Split the duration column

df[['minute','unit']] = df['Duration'].str.split(" ", expand = True)

# %%
# Analyzing data

df.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil   2020-08-14
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico   2016-12-23
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1  TV-MA     93 min                       Dramas, International Movies
#
#                                          Description  year minute     unit
# 0  In a future where the elite inhabit an island ...  2020      4  Seasons
# 1  After a devastating earthquake hits Mexico Cit...  2016     93      min

# %%
# Changing data type

df['minute'] = df['minute'].astype('int64')

# %%
# The maximum duration of a Movie on Netflix

df[df['Category'] == 'Movie']['minute'].max()
# Out:
# 312

# %% [markdown]
# ### Question 15 : Which individual country has the Highest No. of TV Shows ?

# %%
# Analyzing data

df.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil   2020-08-14
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico   2016-12-23
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1  TV-MA     93 min                       Dramas, International Movies
#
#                                          Description  year
# 0  In a future where the elite inhabit an island ...  2020
# 1  After a devastating earthquake hits Mexico Cit...  2016

# %%
# Records of TV Show

df[df['Category'] == 'TV Show']
# Out:
#      Show_Id Category                  Title              Director  \
# 0         s1  TV Show                     3%                   NaN
# 5         s6  TV Show                     46           Serdar Akar
# 11       s12  TV Show                   1983                   NaN
# 12       s13  TV Show                   1994  Diego Enrique Osorno
# 16       s17  TV Show                 Feb-09                   NaN
# ...      ...      ...                    ...                   ...
# 7769   s7768  TV Show     Zindagi Gulzar Hai                   NaN
# 7777   s7776  TV Show             Zoids Wild                   NaN
# 7779   s7778  TV Show            Zombie Dumb                   NaN
# 7781   s7780  TV Show              Zona Rosa                   NaN
# 7787   s7786  TV Show  Zumbo's Just Desserts                   NaN
#
#                                                    Cast  \
# 0     João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
# Country with the Highest No. of TV Shows 

df[df['Category'] == 'TV Show'].groupby(['Country'])['Category'].count().sort_values(ascending = False).head(10)
# Out:
# Country
# United States     705
# United Kingdom    204
# Japan             157
# South Korea       147
# India              71
# Taiwan             68
# Canada             59
# Australia          46
# France             46
# Spain              45
# Name: Category, dtype: int64

# %% [markdown]
# ### Question 16 : Sort the dataset by Year ?

# %%
# Analyzing data

df.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil   2020-08-14
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico   2016-12-23
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1  TV-MA     93 min                       Dramas, International Movies
#
#                                          Description  year
# 0  In a future where the elite inhabit an island ...  2020
# 1  After a devastating earthquake hits Mexico Cit...  2016

# %%
#  dataset by Year

df.sort_values(by = 'year')
# Out:
#      Show_Id Category                         Title              Director  \
# 7115   s7114    Movie          To and From New York  Sorin Dan Mihalcescu
# 1765   s1766  TV Show               Dinner for Five                   NaN
# 5766   s5766    Movie                      Splatter             Joe Dante
# 3248   s3249    Movie       Just Another Love Story          Ole Bornedal
# 3840   s3841    Movie   Mad Ron's Prevues from Hell            Jim Monaco
# ...      ...      ...                           ...                   ...
# 3374   s3375  TV Show                      Kikoriki                   NaN
# 3492   s3493  TV Show           La Familia P. Luche                   NaN
# 3946   s3947  TV Show                         Maron                   NaN
# 5138   s5138  TV Show                  Red vs. Blue                   NaN
# 6066   s6066  TV Show  The Adventures of Figaro Pho                   NaN
#
#                                                    Cast        Country  \
# ...

# %% [markdown]
# ### Question 17 : Records where Category is Movie & Type is Dramas or Category is TV Show & Type is Kids TV

# %%
# Analyzing data 

df.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil   2020-08-14
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico   2016-12-23
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1  TV-MA     93 min                       Dramas, International Movies
#
#                                          Description  year
# 0  In a future where the elite inhabit an island ...  2020
# 1  After a devastating earthquake hits Mexico Cit...  2016

# %%
# Records were category is Movie & Type is Dramas or Category is TV Show & Type is Kids TV

df[((df['Category'] == 'Movie') & (df['Type'].str.contains('Dramas',na=False))) | 
   ((df['Category'] == 'TV Show') & (df['Type'].str.contains('Kids TV',na=False)))]
# Out:
#      Show_Id Category     Title           Director  \
# 1         s2    Movie     07:19  Jorge Michel Grau
# 4         s5    Movie        21     Robert Luketic
# 7         s8    Movie       187     Kevin Reynolds
# 10       s11    Movie      1922       Zak Hilditch
# 15       s16    Movie    Oct-01     Kunle Afolayan
# ...      ...      ...       ...                ...
# 7776   s7775    Movie    Zodiac      David Fincher
# 7778   s7777    Movie  Zokkomon   Satyajit Bhatkal
# 7782   s7781    Movie       Zoo       Shlok Sharma
# 7784   s7783    Movie      Zozo        Josef Fares
# 7785   s7784    Movie    Zubaan        Mozez Singh
#
#                                                    Cast  \
# 1     Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# 7     Samuel L. Jackson, John Heard, Kelly Rowan, Cl...
# 10    Thomas Jane, Molly Parker, Dylan Schmid, Kaitl...
# 15    Sadiq Daba, David Bailie, Kayode Olaiya, Kehin...
# ...
